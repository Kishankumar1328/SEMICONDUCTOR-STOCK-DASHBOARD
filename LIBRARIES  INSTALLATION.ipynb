# %%
pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in c:\users\s.ragul\anaconda3\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from cufflinks) (1.24.3)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from cufflinks) (2.0.3)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from cufflinks) (5.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from cufflinks) (68.0.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from cufflinks) (8.15.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from cufflinks) (8.0.4)
# Requirement already satisfied: backcall in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: decorator in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.7.1)
# Requirement already satisfied: colorama in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (6.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (8.2.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.6)
# Requirement already satisfied: packaging in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (23.1)
# Requirement already satisfied: psutil in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\s.ragul\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: executing in c:\users\s.ragul\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\s.ragul\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\s.ragul\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: entrypoints in c:\users\s.ragul\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\s.ragul\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (305.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mercury
# Out:
# Collecting mercury
#   Using cached mercury-2.3.7-py3-none-any.whl
# Collecting django==4.2.2 (from mercury)
#   Obtaining dependency information for django==4.2.2 from https://files.pythonhosted.org/packages/ba/f3/7a66888bda4017198a692887bd566123732783073c1fd424db15358525fd/Django-4.2.2-py3-none-any.whl.metadata
#   Using cached Django-4.2.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting djangorestframework==3.14.0 (from mercury)
#   Using cached djangorestframework-3.14.0-py3-none-any.whl (1.1 MB)
# Collecting django-filter==21.1 (from mercury)
#   Using cached django_filter-21.1-py3-none-any.whl (81 kB)
# Collecting markdown==3.3.6 (from mercury)
#   Using cached Markdown-3.3.6-py3-none-any.whl (97 kB)
# Collecting celery>=5.1.2 (from mercury)
#   Obtaining dependency information for celery>=5.1.2 from https://files.pythonhosted.org/packages/37/c2/4c8a67a4d98a6fcd55dbdd79b641f945d7f59637c3e885c4abbda3c431f6/celery-5.3.6-py3-none-any.whl.metadata
#   Using cached celery-5.3.6-py3-none-any.whl.metadata (21 kB)
# Collecting sqlalchemy==1.4.27 (from mercury)
#   Using cached SQLAlchemy-1.4.27-cp311-cp311-win_amd64.whl
# Collecting gevent (from mercury)
#   Obtaining dependency information for gevent from https://files.pythonhosted.org/packages/a0/98/5a074e2b7006e627ea72e8be96d83801a2037bf60efd517e5d432aa93bd0/gevent-23.9.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached gevent-23.9.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting nbconvert>=7.8.0 (from mercury)
#   Obtaining dependency information for nbconvert>=7.8.0 from https://files.pythonhosted.org/packages/dc/d6/aac1997cd0342b17a2282ee0cc9130507b774cebd213e3f52127c2e08812/nbconvert-7.13.0-py3-none-any.whl.metadata
#   Using cached nbconvert-7.13.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: ipython-genutils in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (0.2.0)
# Requirement already satisfied: pyyaml==6.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (6.0)
# Collecting django-cors-headers==3.10.1 (from mercury)
#   Using cached django_cors_headers-3.10.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: ipython>=7.30.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (8.15.0)
# Requirement already satisfied: ipykernel>=6.6.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (6.25.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (5.9.0)
# Requirement already satisfied: whitenoise>=5.3.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (6.6.0)
# Requirement already satisfied: python-dotenv>=0.19.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (0.21.0)
# Collecting django-drf-filepond==0.4.1 (from mercury)
#   Using cached django_drf_filepond-0.4.1-py2.py3-none-any.whl (39 kB)
# Collecting croniter>=1.3.5 (from mercury)
#   Obtaining dependency information for croniter>=1.3.5 from https://files.pythonhosted.org/packages/27/86/c1ce37af79385a106aacdd40b6e25ff25b2d888f2e64a05ee4e5b05f5768/croniter-2.0.1-py2.py3-none-any.whl.metadata
#   Using cached croniter-2.0.1-py2.py3-none-any.whl.metadata (24 kB)
# Collecting pyppeteer==1.0.2 (from mercury)
#   Using cached pyppeteer-1.0.2-py3-none-any.whl (83 kB)
# Collecting channels[daphne]>=4.0.0 (from mercury)
#   Using cached channels-4.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: websocket-client>=1.4.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (1.7.0)
# Collecting execnb (from mercury)
#   Using cached execnb-0.1.5-py3-none-any.whl (13 kB)
# Collecting ipywidgets==8.0.3 (from mercury)
#   Using cached ipywidgets-8.0.3-py3-none-any.whl (137 kB)
# Collecting dj-rest-auth[with_social]==3.0.0 (from mercury)
#   Using cached dj_rest_auth-3.0.0-py2.py3-none-any.whl
# Collecting boto3==1.26.83 (from mercury)
#   Using cached boto3-1.26.83-py3-none-any.whl (134 kB)
# Requirement already satisfied: cryptography in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (41.0.3)
# Requirement already satisfied: pyopenssl>=23.1.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from mercury) (23.2.0)
# Collecting bleach>=6.0.0 (from mercury)
#   Obtaining dependency information for bleach>=6.0.0 from https://files.pythonhosted.org/packages/ea/63/da7237f805089ecc28a3f36bca6a21c31fcbc2eb380f3b8f1be3312abd14/bleach-6.1.0-py3-none-any.whl.metadata
#   Using cached bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting botocore<1.30.0,>=1.29.83 (from boto3==1.26.83->mercury)
#   Obtaining dependency information for botocore<1.30.0,>=1.29.83 from https://files.pythonhosted.org/packages/46/20/e7a9a8e6746872afcc4e3ad5ab503702c38813b3a532df27cce95c98b8cb/botocore-1.29.165-py3-none-any.whl.metadata
#   Using cached botocore-1.29.165-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from boto3==1.26.83->mercury) (0.10.0)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3==1.26.83->mercury)
#   Obtaining dependency information for s3transfer<0.7.0,>=0.6.0 from https://files.pythonhosted.org/packages/d9/17/a3b666f5ef9543cfd3c661d39d1e193abb9649d0cfbbfee3cf3b51d5af02/s3transfer-0.6.2-py3-none-any.whl.metadata
#   Using cached s3transfer-0.6.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting django-allauth<0.53.0,>=0.40.0 (from dj-rest-auth[with_social]==3.0.0->mercury)
#   Using cached django_allauth-0.52.0-py3-none-any.whl
# Collecting asgiref<4,>=3.6.0 (from django==4.2.2->mercury)
#   Obtaining dependency information for asgiref<4,>=3.6.0 from https://files.pythonhosted.org/packages/9b/80/b9051a4a07ad231558fcd8ffc89232711b4e618c15cb7a392a17384bbeef/asgiref-3.7.2-py3-none-any.whl.metadata
#   Using cached asgiref-3.7.2-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: sqlparse>=0.3.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from django==4.2.2->mercury) (0.4.4)
# Requirement already satisfied: tzdata in c:\users\s.ragul\anaconda3\lib\site-packages (from django==4.2.2->mercury) (2023.3)
# Requirement already satisfied: requests>=2.20.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from django-drf-filepond==0.4.1->mercury) (2.31.0)
# Requirement already satisfied: six>=1.14.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from django-drf-filepond==0.4.1->mercury) (1.16.0)
# Requirement already satisfied: shortuuid>=0.5.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from django-drf-filepond==0.4.1->mercury) (1.0.11)
# Collecting django-storages>=1.9.1 (from django-drf-filepond==0.4.1->mercury)
#   Obtaining dependency information for django-storages>=1.9.1 from https://files.pythonhosted.org/packages/b2/5f/124d304984bbec65a925b5fec38dcda159a32422101f115b9cf66678ead1/django_storages-1.14.2-py3-none-any.whl.metadata
#   Using cached django_storages-1.14.2-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: pytz in c:\users\s.ragul\anaconda3\lib\site-packages (from djangorestframework==3.14.0->mercury) (2023.3.post1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipywidgets==8.0.3->mercury) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipywidgets==8.0.3->mercury) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipywidgets==8.0.3->mercury) (3.0.5)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\s.ragul\anaconda3\lib\site-packages (from pyppeteer==1.0.2->mercury) (1.4.4)
# Requirement already satisfied: certifi>=2021 in c:\users\s.ragul\anaconda3\lib\site-packages (from pyppeteer==1.0.2->mercury) (2023.11.17)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\s.ragul\anaconda3\lib\site-packages (from pyppeteer==1.0.2->mercury) (6.0.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from pyppeteer==1.0.2->mercury) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from pyppeteer==1.0.2->mercury) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\s.ragul\anaconda3\lib\site-packages (from pyppeteer==1.0.2->mercury) (1.26.16)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from pyppeteer==1.0.2->mercury) (10.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\s.ragul\anaconda3\lib\site-packages (from sqlalchemy==1.4.27->mercury) (2.0.1)
# Requirement already satisfied: webencodings in c:\users\s.ragul\anaconda3\lib\site-packages (from bleach>=6.0.0->mercury) (0.5.1)
# Collecting billiard<5.0,>=4.2.0 (from celery>=5.1.2->mercury)
#   Obtaining dependency information for billiard<5.0,>=4.2.0 from https://files.pythonhosted.org/packages/50/8d/6e9fdeeab04d803abc5a715175f87e88893934d5590595eacff23ca12b07/billiard-4.2.0-py3-none-any.whl.metadata
#   Using cached billiard-4.2.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting click-didyoumean>=0.3.0 (from celery>=5.1.2->mercury)
#   Using cached click_didyoumean-0.3.0-py3-none-any.whl (2.7 kB)
# Collecting click-plugins>=1.1.1 (from celery>=5.1.2->mercury)
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting click-repl>=0.2.0 (from celery>=5.1.2->mercury)
#   Obtaining dependency information for click-repl>=0.2.0 from https://files.pythonhosted.org/packages/52/40/9d857001228658f0d59e97ebd4c346fe73e138c6de1bce61dc568a57c7f8/click_repl-0.3.0-py3-none-any.whl.metadata
#   Using cached click_repl-0.3.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting click<9.0,>=8.1.2 (from celery>=5.1.2->mercury)
#   Obtaining dependency information for click<9.0,>=8.1.2 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting kombu<6.0,>=5.3.4 (from celery>=5.1.2->mercury)
#   Obtaining dependency information for kombu<6.0,>=5.3.4 from https://files.pythonhosted.org/packages/a8/cc/24160d61e8c44bd76a775017c0859a403db471ddbd701e725fdf2becafa6/kombu-5.3.4-py3-none-any.whl.metadata
#   Using cached kombu-5.3.4-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from celery>=5.1.2->mercury) (2.8.2)
# Requirement already satisfied: vine<6.0,>=5.1.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from celery>=5.1.2->mercury) (5.1.0)
# Collecting daphne>=4.0.0 (from channels[daphne]>=4.0.0->mercury)
#   Using cached daphne-4.0.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=6.6.0->mercury) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=6.6.0->mercury) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=6.6.0->mercury) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=6.6.0->mercury) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=6.6.0->mercury) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=6.6.0->mercury) (1.5.6)
# Requirement already satisfied: packaging in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=6.6.0->mercury) (23.1)
# Requirement already satisfied: pyzmq>=20 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=6.6.0->mercury) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipykernel>=6.6.0->mercury) (6.3.2)
# Requirement already satisfied: backcall in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=7.30.1->mercury) (0.2.0)
# Requirement already satisfied: decorator in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=7.30.1->mercury) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=7.30.1->mercury) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=7.30.1->mercury) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=7.30.1->mercury) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=7.30.1->mercury) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=7.30.1->mercury) (0.2.0)
# Requirement already satisfied: colorama in c:\users\s.ragul\anaconda3\lib\site-packages (from ipython>=7.30.1->mercury) (0.4.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\s.ragul\anaconda3\lib\site-packages (from nbconvert>=7.8.0->mercury) (4.12.2)
# Requirement already satisfied: defusedxml in c:\users\s.ragul\anaconda3\lib\site-packages (from nbconvert>=7.8.0->mercury) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from nbconvert>=7.8.0->mercury) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\s.ragul\anaconda3\lib\site-packages (from nbconvert>=7.8.0->mercury) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from nbconvert>=7.8.0->mercury) (2.1.1)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=7.8.0->mercury)
#   Obtaining dependency information for mistune<4,>=2.0.3 from https://files.pythonhosted.org/packages/f0/74/c95adcdf032956d9ef6c89a9b8a5152bf73915f8c633f3e3d88d06bd699c/mistune-3.0.2-py3-none-any.whl.metadata
#   Using cached mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from nbconvert>=7.8.0->mercury) (0.5.13)
# Requirement already satisfied: nbformat>=5.7 in c:\users\s.ragul\anaconda3\lib\site-packages (from nbconvert>=7.8.0->mercury) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from nbconvert>=7.8.0->mercury) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\s.ragul\anaconda3\lib\site-packages (from nbconvert>=7.8.0->mercury) (1.2.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\s.ragul\anaconda3\lib\site-packages (from cryptography->mercury) (1.15.1)
# Collecting fastcore>=1.5.5 (from execnb->mercury)
#   Using cached fastcore-1.5.29-py3-none-any.whl (67 kB)
# Requirement already satisfied: zope.event in c:\users\s.ragul\anaconda3\lib\site-packages (from gevent->mercury) (5.0)
# Requirement already satisfied: zope.interface in c:\users\s.ragul\anaconda3\lib\site-packages (from gevent->mercury) (5.4.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy==1.4.27->mercury)
#   Obtaining dependency information for greenlet!=0.4.17 from https://files.pythonhosted.org/packages/82/46/09045a85d4df1b63433c557663ffac664ce7797f21691a16ddebca4f4b56/greenlet-3.0.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached greenlet-3.0.2-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: pycparser in c:\users\s.ragul\anaconda3\lib\site-packages (from cffi>=1.12->cryptography->mercury) (2.21)
# Requirement already satisfied: twisted[tls]>=22.4 in c:\users\s.ragul\anaconda3\lib\site-packages (from daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (22.10.0)
# Collecting autobahn>=22.4.2 (from daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Using cached autobahn-23.6.2-cp311-cp311-win_amd64.whl
# Requirement already satisfied: python3-openid>=3.0.8 in c:\users\s.ragul\anaconda3\lib\site-packages (from django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury) (3.2.0)
# Requirement already satisfied: requests-oauthlib>=0.3.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury) (1.3.1)
# Requirement already satisfied: pyjwt[crypto]>=1.7 in c:\users\s.ragul\anaconda3\lib\site-packages (from django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury) (2.4.0)
# Requirement already satisfied: pip in c:\users\s.ragul\anaconda3\lib\site-packages (from fastcore>=1.5.5->execnb->mercury) (23.2.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer==1.0.2->mercury) (3.11.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.30.1->mercury) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\s.ragul\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.6.0->mercury) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.6.0->mercury) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\s.ragul\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.6.0->mercury) (305.1)
# Collecting amqp<6.0.0,>=5.1.1 (from kombu<6.0,>=5.3.4->celery>=5.1.2->mercury)
#   Obtaining dependency information for amqp<6.0.0,>=5.1.1 from https://files.pythonhosted.org/packages/b3/f0/8e5be5d5e0653d9e1d02b1144efa33ff7d2963dfad07049e02c0fa9b2e8d/amqp-5.2.0-py3-none-any.whl.metadata
#   Using cached amqp-5.2.0-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: fastjsonschema in c:\users\s.ragul\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert>=7.8.0->mercury) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\s.ragul\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert>=7.8.0->mercury) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\s.ragul\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.30.1->mercury) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\s.ragul\anaconda3\lib\site-packages (from requests>=2.20.1->django-drf-filepond==0.4.1->mercury) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from requests>=2.20.1->django-drf-filepond==0.4.1->mercury) (3.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=7.8.0->mercury) (2.4)
# Requirement already satisfied: executing in c:\users\s.ragul\anaconda3\lib\site-packages (from stack-data->ipython>=7.30.1->mercury) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\s.ragul\anaconda3\lib\site-packages (from stack-data->ipython>=7.30.1->mercury) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\s.ragul\anaconda3\lib\site-packages (from stack-data->ipython>=7.30.1->mercury) (0.2.2)
# Requirement already satisfied: setuptools in c:\users\s.ragul\anaconda3\lib\site-packages (from zope.event->gevent->mercury) (68.0.0)
# Requirement already satisfied: txaio>=21.2.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from autobahn>=22.4.2->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (23.1.1)
# Requirement already satisfied: hyperlink>=21.0.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from autobahn>=22.4.2->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (21.0.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.8.0->mercury) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.8.0->mercury) (0.18.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from requests-oauthlib>=0.3.0->django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury) (3.2.2)
# Requirement already satisfied: constantly>=15.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (21.3.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (20.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (4.7.1)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (1.0.2)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (18.1.0)
# Requirement already satisfied: pyasn1-modules in c:\users\s.ragul\anaconda3\lib\site-packages (from service-identity>=18.1.0->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (0.2.8)
# Requirement already satisfied: pyasn1 in c:\users\s.ragul\anaconda3\lib\site-packages (from service-identity>=18.1.0->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (0.4.8)
# Using cached Django-4.2.2-py3-none-any.whl (8.0 MB)
# Using cached bleach-6.1.0-py3-none-any.whl (162 kB)
# Using cached celery-5.3.6-py3-none-any.whl (422 kB)
# Using cached croniter-2.0.1-py2.py3-none-any.whl (19 kB)
# Using cached nbconvert-7.13.0-py3-none-any.whl (256 kB)
# Using cached gevent-23.9.1-cp311-cp311-win_amd64.whl (1.5 MB)
# Using cached asgiref-3.7.2-py3-none-any.whl (24 kB)
# Using cached billiard-4.2.0-py3-none-any.whl (86 kB)
# Using cached botocore-1.29.165-py3-none-any.whl (11.0 MB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached click_repl-0.3.0-py3-none-any.whl (10 kB)
# Using cached django_storages-1.14.2-py3-none-any.whl (47 kB)
# Using cached greenlet-3.0.2-cp311-cp311-win_amd64.whl (289 kB)
# Using cached kombu-5.3.4-py3-none-any.whl (199 kB)
# Using cached mistune-3.0.2-py3-none-any.whl (47 kB)
# Using cached s3transfer-0.6.2-py3-none-any.whl (79 kB)
# Using cached amqp-5.2.0-py3-none-any.whl (50 kB)
# Installing collected packages: mistune, markdown, greenlet, fastcore, click, bleach, billiard, asgiref, amqp, sqlalchemy, pyppeteer, kombu, gevent, django, croniter, click-repl, click-plugins, click-didyoumean, botocore, s3transfer, djangorestframework, django-storages, django-filter, django-cors-headers, channels, celery, autobahn, nbconvert, execnb, django-drf-filepond, django-allauth, dj-rest-auth, boto3, ipywidgets, daphne, mercury
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.4.1
#     Uninstalling Markdown-3.4.1:
#       Successfully uninstalled Markdown-3.4.1
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 2.0.1
#     Uninstalling greenlet-2.0.1:
#       Successfully uninstalled greenlet-2.0.1
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
#   Attempting uninstall: bleach
#     Found existing installation: bleach 4.1.0
#     Uninstalling bleach-4.1.0:
#       Successfully uninstalled bleach-4.1.0
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.29.76
#     Uninstalling botocore-1.29.76:
#       Successfully uninstalled botocore-1.29.76
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.5.4
#     Uninstalling nbconvert-6.5.4:
#       Successfully uninstalled nbconvert-6.5.4
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.0.4
#     Uninstalling ipywidgets-8.0.4:
#       Successfully uninstalled ipywidgets-8.0.4
# Successfully installed amqp-5.2.0 asgiref-3.7.2 autobahn-23.6.2 billiard-4.2.0 bleach-6.1.0 boto3-1.26.83 botocore-1.29.165 celery-5.3.6 channels-4.0.0 click-8.1.7 click-didyoumean-0.3.0 click-plugins-1.1.1 click-repl-0.3.0 croniter-2.0.1 daphne-4.0.0 dj-rest-auth-3.0.0 django-4.2.2 django-allauth-0.52.0 django-cors-headers-3.10.1 django-drf-filepond-0.4.1 django-filter-21.1 django-storages-1.14.2 djangorestframework-3.14.0 execnb-0.1.5 fastcore-1.5.29 gevent-23.9.1 greenlet-3.0.2 ipywidgets-8.0.3 kombu-5.3.4 markdown-3.3.6 mercury-2.3.7 mistune-3.0.2 nbconvert-7.13.0 pyppeteer-1.0.2 s3transfer-0.6.2 sqlalchemy-1.4.27
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.5.0 requires botocore<1.29.77,>=1.29.76, but you have botocore 1.29.165 which is incompatible.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.

# %%
conda install -c conda-forge mercury
# Out:
# Note: you may need to restart the kernel to use updated packages.
# No installed Python found!

# %%
pip install python-dateutil
# Out:
# Requirement already satisfied: python-dateutil in c:\users\s.ragul\anaconda3\lib\site-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from python-dateutil) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/09/82/5a5eee685095a6c1f8968db75bba8536baa8046c970be25e1ac91a843839/yfinance-0.2.33-py2.py3-none-any.whl.metadata
#   Downloading yfinance-0.2.33-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\s.ragul\anaconda3\lib\site-packages (from yfinance) (2.0.3)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: numpy>=1.16.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from yfinance) (1.24.3)
#
# Requirement already satisfied: requests>=2.31 in c:\users\s.ragul\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\s.ragul\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Obtaining dependency information for frozendict>=2.3.4 from https://files.pythonhosted.org/packages/b6/2c/e391d6d57bbd837d383a6b69b54ecb4768d75b31d8bc7a380b4b4afe4cb2/frozendict-2.3.10-py3-none-any.whl.metadata
#   Downloading frozendict-2.3.10-py3-none-any.whl.metadata (20 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.17.0-py3-none-any.whl
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\s.ragul\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\s.ragul\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\s.ragul\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\s.ragul\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\s.ragul\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\s.ragul\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\s.ragul\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.11.17)
# Downloading yfinance-0.2.33-py2.py3-none-any.whl (69 kB)
#    ---------------------------------------- 0.0/69.0 kB ? eta -:--:--
#    ----------------------------------- ---- 61.4/69.0 kB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 61.4/69.0 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 69.0/69.0 kB 539.2 kB/s eta 0:00:00
# Downloading frozendict-2.3.10-py3-none-any.whl (14 kB)
# Installing collected packages: peewee, multitasking, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.3.10 html5lib-1.1 multitasking-0.0.11 peewee-3.17.0 yfinance-0.2.33
